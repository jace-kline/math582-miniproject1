# %% [markdown]
# # Data Cleaning

# %%
import numpy as np
import pandas as pd
import re
from functools import reduce

# %%
df = pd.read_csv("../data/original.csv")
df.head()
# Out:
#    Unnamed: 0  Pos                       Name                     Club  \
# 0           1    1            FRODENO Jan (2)        Laz  Saarbruecken
# 1           2    2        CLAVEL Maurice (24)                      NaN
# 2           3    3  TAAGHOLT Miki  Morck (21)                    Ttsdu
# 3           4    4         STRATMANN Jan (13)  Triathlon  Team  Witten
# 4           5    5       MOLINARI Giulio (22)        C. S. Carabinieri
#
#         Cat        Swim          T1       Bike          T2         Run  \
# 0  MPRO - 1   00:22:501  00:01:2710  02:02:011  00:01:5221   01:11:252
# 1  MPRO - 2  00:23:3311  00:01:3015  02:04:543   00:01:323   01:12:144
# 2  MPRO - 3   00:22:574   00:01:141  02:05:526  00:02:0148   01:14:238
# 3  MPRO - 4   00:22:502  00:01:3118  02:08:208  00:01:5633   01:13:336
# 4  MPRO - 5   00:22:585  00:01:4968  02:05:114  00:02:0768  01:17:2117
#
#        Time
# 0  03:39:35
# 1  03:43:43
# 2  03:46:27
# 3  03:48:10
# 4  03:49:26

# %% [markdown]
# ### Remove Uninteresting Columns
#
# We initially remove the unnamed column, the athlete name, and the club.

# %%
cols = df.columns
df.drop(columns=[cols[0], 'Name', 'Club'], inplace=True)
df.head()
# Out:
#    Pos       Cat        Swim          T1       Bike          T2         Run  \
# 0    1  MPRO - 1   00:22:501  00:01:2710  02:02:011  00:01:5221   01:11:252
# 1    2  MPRO - 2  00:23:3311  00:01:3015  02:04:543   00:01:323   01:12:144
# 2    3  MPRO - 3   00:22:574   00:01:141  02:05:526  00:02:0148   01:14:238
# 3    4  MPRO - 4   00:22:502  00:01:3118  02:08:208  00:01:5633   01:13:336
# 4    5  MPRO - 5   00:22:585  00:01:4968  02:05:114  00:02:0768  01:17:2117
#
#        Time
# 0  03:39:35
# 1  03:43:43
# 2  03:46:27
# 3  03:48:10
# 4  03:49:26

# %%
# Helper functions for processing/filtering

def all(ls: list) -> bool:
    return reduce(lambda a, b: a and b, ls)

def startswith(s: str, prefix: str) -> bool:
    s_ = str(s)
    return (len(s_) >= len(prefix)) and all(map(lambda tup: tup[0] == tup[1], zip(s_,prefix)))

def indexof(v, arr) -> int:
    for i, x in enumerate(arr):
        if v == x:
            return i
    return -1

# %% [markdown]
# ### Convert 'Cat' column into 'Gender' and 'AgeGroup' columns

# %%
# Remove the Category placing suffix

def parsecategory(s: str) -> str:
    s_ = str(s)
    res = re.split(r"\W+", s_)
    return res[0] if len(res) > 0 else ""

# return 0 for female, 1 for male
def parsegender(cat: str) -> int:
    if cat[0] == 'F':
        return 0
    elif cat[0] == 'M':
        return 1
    else:
        return -1

parsed_cats = df['Cat'].apply(parsecategory)
df['Gender'] = parsed_cats.apply(parsegender)

agegroups = parsed_cats.apply(lambda ag: ag[1:])
df['AgeGroup'] = agegroups.apply(lambda v: indexof(v, np.unique(agegroups)))

df = df.loc[df['Gender'] != -1]

df.drop(columns=['Cat'], inplace=True)
df.head()
# Out:
#    Pos        Swim          T1       Bike          T2         Run      Time  \
# 0    1   00:22:501  00:01:2710  02:02:011  00:01:5221   01:11:252  03:39:35
# 1    2  00:23:3311  00:01:3015  02:04:543   00:01:323   01:12:144  03:43:43
# 2    3   00:22:574   00:01:141  02:05:526  00:02:0148   01:14:238  03:46:27
# 3    4   00:22:502  00:01:3118  02:08:208  00:01:5633   01:13:336  03:48:10
# 4    5   00:22:585  00:01:4968  02:05:114  00:02:0768  01:17:2117  03:49:26
#
#    Gender  AgeGroup
# 0       1         9
# 1       1         9
# 2       1         9
# 3       1         9
# 4       1         9

# %% [markdown]
# ### Parse the time fields into seconds

# %%
def parsetime(s: str) -> float:
    res = re.split(':', s)
    if len(res) != 3:
        return 0
    else:
        hrs, mins, secs = res
        secs = secs[0:2]
        return 60*60*int(hrs) + 60*int(mins) + int(secs)

# %%
timecols = ['Swim', 'T1', 'Bike', 'T2', 'Run', 'Time']
timecols

for timecol in timecols:
    df[timecol] = df[timecol].apply(parsetime)

# %%
# remove any rows with values of 0

df = df.loc[df[timecols].apply(lambda row: all(map(lambda col: col != 0, [row[col] for col in timecols])), axis=1)]
df
# Out:
#      Pos  Swim   T1  Bike   T2   Run   Time  Gender  AgeGroup
# 0      1  1370   87  7321  112  4285  13175       1         9
# 1      2  1413   90  7494   92  4334  13423       1         9
# 2      3  1377   74  7552  121  4463  13587       1         9
# 3      4  1370   91  7700  116  4413  13690       1         9
# 4      5  1378  109  7511  127  4641  13766       1         9
# ..   ...   ...  ...   ...  ...   ...    ...     ...       ...
# 795  796  2345  213  9887  208  6624  19277       1         3
# 796  797  2201  200  9913  237  6727  19278       1         5
# 797  798  2481  338  9599  163  6698  19279       1         3
# 798  799  2436  128  9676  168  6878  19286       1         4
# 799  800  2230  278  9702  292  6785  19286       1         4
#
# [797 rows x 9 columns]

# %% [markdown]
# ### Output Clean Data to CSV

# %%
df.to_csv('../data/cleaned.csv')
